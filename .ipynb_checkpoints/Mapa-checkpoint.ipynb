# %%
import folium as fl

poa = [-30.0346, -51.2177]
sp = [-23.5505, -46.6333]
rj = [-22.9068, -43.1729]
cr = [-25.4290, -49.2671]
bh = [-19.9173, -43.9345]

mapa = fl.Map(location=[sp[0],sp[1]], zoom_start=5)

fl.Marker([poa[0], poa[1]], popup='Porto Alegre, RS, Brasil').add_to(mapa)
fl.Marker([sp[0], sp[1]], popup='São Paulo, SP, Brasil').add_to(mapa)
fl.Marker([rj[0], rj[1]], popup='Rio de Janeiro, RJ, Brasil').add_to(mapa)
fl.Marker([cr[0], cr[1]], popup='Curitiba, PR, Brasil').add_to(mapa)
fl.Marker([bh[0], bh[1]], popup='Belo Horizonte, MG, Brasil').add_to(mapa)

mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_01639dc1ab307bc9d6ea83a97494bb13 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_01639dc1ab307bc9d6ea83a97494bb13&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_01639dc1ab307bc9d6ea83a97494bb13 = L.map(
#                 &quot;map_01639dc1ab307bc9d6ea83a97494bb13&quot;,
#                 {
#                     center: [-23.5505, -46.6333],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e39b17d21f86eb06bac6edde9e34aba2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_e39b17d21f86eb06bac6edde9e34aba2.addTo(map_01639dc1ab307bc9d6ea83a97494bb13);
#
#
#             var marker_3165110ef4f0e55df55ced6722b8c1d8 = L.marker(
#                 [-30.0346, -51.2177],
#                 {}
#             ).addTo(map_01639dc1ab307bc9d6ea83a97494bb13);
#
#
#         var popup_9d256d0f9fb853b92c798958fa9192e4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_007a80ddfa4ed38f78e1c6319d9aacd6 = $(`&lt;div id=&quot;html_007a80ddfa4ed38f78e1c6319d9aacd6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Porto Alegre, RS, Brasil&lt;/div&gt;`)[0];
#                 popup_9d256d0f9fb853b92c798958fa9192e4.setContent(html_007a80ddfa4ed38f78e1c6319d9aacd6);
#
#
#
#         marker_3165110ef4f0e55df55ced6722b8c1d8.bindPopup(popup_9d256d0f9fb853b92c798958fa9192e4)
#         ;
#
#
#
#
#             var marker_99f5ab5b9ca0c8a15ad3b9ab11b14b08 = L.marker(
#                 [-23.5505, -46.6333],
#                 {}
#             ).addTo(map_01639dc1ab307bc9d6ea83a97494bb13);
#
#
#         var popup_f2de27d4a3a5347e52b94542a4efefad = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_cc6a37af636c66317e331d999759e062 = $(`&lt;div id=&quot;html_cc6a37af636c66317e331d999759e062&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;São Paulo, SP, Brasil&lt;/div&gt;`)[0];
#                 popup_f2de27d4a3a5347e52b94542a4efefad.setContent(html_cc6a37af636c66317e331d999759e062);
#
#
#
#         marker_99f5ab5b9ca0c8a15ad3b9ab11b14b08.bindPopup(popup_f2de27d4a3a5347e52b94542a4efefad)
#         ;
#
#
#
#
#             var marker_ad029c263c5a8ff14644da781bf07a65 = L.marker(
#                 [-22.9068, -43.1729],
#                 {}
#             ).addTo(map_01639dc1ab307bc9d6ea83a97494bb13);
#
#
#         var popup_ce44f368e3cc9246368bbefe200d4d99 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_895acdb5c1a3bc2319f10cfe0460d8ea = $(`&lt;div id=&quot;html_895acdb5c1a3bc2319f10cfe0460d8ea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Rio de Janeiro, RJ, Brasil&lt;/div&gt;`)[0];
#                 popup_ce44f368e3cc9246368bbefe200d4d99.setContent(html_895acdb5c1a3bc2319f10cfe0460d8ea);
#
#
#
#         marker_ad029c263c5a8ff14644da781bf07a65.bindPopup(popup_ce44f368e3cc9246368bbefe200d4d99)
#         ;
#
#
#
#
#             var marker_96b5d3d55b00ce8cf29bd41e4237ae98 = L.marker(
#                 [-25.429, -49.2671],
#                 {}
#             ).addTo(map_01639dc1ab307bc9d6ea83a97494bb13);
#
#
#         var popup_7addd67d352ec266b9c011321209d399 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_35c5484a5971a0ded3e8931d250cebc9 = $(`&lt;div id=&quot;html_35c5484a5971a0ded3e8931d250cebc9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Curitiba, PR, Brasil&lt;/div&gt;`)[0];
#                 popup_7addd67d352ec266b9c011321209d399.setContent(html_35c5484a5971a0ded3e8931d250cebc9);
#
#
#
#         marker_96b5d3d55b00ce8cf29bd41e4237ae98.bindPopup(popup_7addd67d352ec266b9c011321209d399)
#         ;
#
#
#
#
#             var marker_4cc24ae4051ae82f50399f0c0d5c3134 = L.marker(
#                 [-19.9173, -43.9345],
#                 {}
#             ).addTo(map_01639dc1ab307bc9d6ea83a97494bb13);
#
#
#         var popup_452a3b6847c2b3a3edde7be4f211d6fe = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_706407cf9d0160b0ac7ed6b16492384d = $(`&lt;div id=&quot;html_706407cf9d0160b0ac7ed6b16492384d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Belo Horizonte, MG, Brasil&lt;/div&gt;`)[0];
#                 popup_452a3b6847c2b3a3edde7be4f211d6fe.setContent(html_706407cf9d0160b0ac7ed6b16492384d);
#
#
#
#         marker_4cc24ae4051ae82f50399f0c0d5c3134.bindPopup(popup_452a3b6847c2b3a3edde7be4f211d6fe)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscre
