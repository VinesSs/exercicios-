# %%
import folium as fl

poa = [-30.0346, -51.2177]
sp = [-23.5505, -46.6333]
rj = [-22.9068, -43.1729]
cr = [-25.4290, -49.2671]
bh = [-19.9173, -43.9345]

mapa = folium.Map(location=[sp[0],sp[1]], zoom_start=5)

fl.Marker([poa[0], poa[1]], popup='Porto Alegre, RS, Brasil').add_to(mapa)
fl.Marker([sp[0], sp[1]], popup='São Paulo, SP, Brasil').add_to(mapa)
fl.Marker([rj[0], rj[1]], popup='Rio de Janeiro, RJ, Brasil').add_to(mapa)
fl.Marker([cr[0], cr[1]], popup='Curitiba, PR, Brasil').add_to(mapa)
fl.Marker([bh[0], bh[1]], popup='Belo Horizonte, MG, Brasil').add_to(mapa)

mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_65846f3d53fb011134853f6a2f0f630c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_65846f3d53fb011134853f6a2f0f630c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_65846f3d53fb011134853f6a2f0f630c = L.map(
#                 &quot;map_65846f3d53fb011134853f6a2f0f630c&quot;,
#                 {
#                     center: [-23.5505, -46.6333],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d8cfbb3436ecf78640a27930daec4b32 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_d8cfbb3436ecf78640a27930daec4b32.addTo(map_65846f3d53fb011134853f6a2f0f630c);
#
#
#             var marker_9acf0663594eb46e121c5b387ccaa9ae = L.marker(
#                 [-30.0346, -51.2177],
#                 {}
#             ).addTo(map_65846f3d53fb011134853f6a2f0f630c);
#
#
#         var popup_5ddc37d5c66aeb340a1bd8d2d9a55a5f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e4afc16ce81b2b69e4edf5df24ab960d = $(`&lt;div id=&quot;html_e4afc16ce81b2b69e4edf5df24ab960d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Porto Alegre, RS, Brasil&lt;/div&gt;`)[0];
#                 popup_5ddc37d5c66aeb340a1bd8d2d9a55a5f.setContent(html_e4afc16ce81b2b69e4edf5df24ab960d);
#
#
#
#         marker_9acf0663594eb46e121c5b387ccaa9ae.bindPopup(popup_5ddc37d5c66aeb340a1bd8d2d9a55a5f)
#         ;
#
#
#
#
#             var marker_b535f3316c3f7edd82ba937d92542194 = L.marker(
#                 [-23.5505, -46.6333],
#                 {}
#             ).addTo(map_65846f3d53fb011134853f6a2f0f630c);
#
#
#         var popup_591051180211f0e54d88e30475136bca = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_531fb9f6a23e1b0d3faa03e0257d87fd = $(`&lt;div id=&quot;html_531fb9f6a23e1b0d3faa03e0257d87fd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;São Paulo, SP, Brasil&lt;/div&gt;`)[0];
#                 popup_591051180211f0e54d88e30475136bca.setContent(html_531fb9f6a23e1b0d3faa03e0257d87fd);
#
#
#
#         marker_b535f3316c3f7edd82ba937d92542194.bindPopup(popup_591051180211f0e54d88e30475136bca)
#         ;
#
#
#
#
#             var marker_4a3cf2694260bfb497119a218cb4ef55 = L.marker(
#                 [-22.9068, -43.1729],
#                 {}
#             ).addTo(map_65846f3d53fb011134853f6a2f0f630c);
#
#
#         var popup_af5b37784d80d3774238395f840ef2e4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_02357875a61fb1d71c8861a6a2386287 = $(`&lt;div id=&quot;html_02357875a61fb1d71c8861a6a2386287&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Rio de Janeiro, RJ, Brasil&lt;/div&gt;`)[0];
#                 popup_af5b37784d80d3774238395f840ef2e4.setContent(html_02357875a61fb1d71c8861a6a2386287);
#
#
#
#         marker_4a3cf2694260bfb497119a218cb4ef55.bindPopup(popup_af5b37784d80d3774238395f840ef2e4)
#         ;
#
#
#
#
#             var marker_39cd266a21d00b54ce5e582e4d0caca3 = L.marker(
#                 [-25.429, -49.2671],
#                 {}
#             ).addTo(map_65846f3d53fb011134853f6a2f0f630c);
#
#
#         var popup_ec17c830d936e77f7941fb3de20f37b6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ea3e4c62e19eaf82c2b15e2c0011ce4d = $(`&lt;div id=&quot;html_ea3e4c62e19eaf82c2b15e2c0011ce4d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Curitiba, PR, Brasil&lt;/div&gt;`)[0];
#                 popup_ec17c830d936e77f7941fb3de20f37b6.setContent(html_ea3e4c62e19eaf82c2b15e2c0011ce4d);
#
#
#
#         marker_39cd266a21d00b54ce5e582e4d0caca3.bindPopup(popup_ec17c830d936e77f7941fb3de20f37b6)
#         ;
#
#
#
#
#             var marker_99df3b52d9253aa025a54d6623743df8 = L.marker(
#                 [-19.9173, -43.9345],
#                 {}
#             ).addTo(map_65846f3d53fb011134853f6a2f0f630c);
#
#
#         var popup_5e421f98c5e86f542ce8f4d50204bb0f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0de02324edccef0c3ed31dbfe9e3ab8e = $(`&lt;div id=&quot;html_0de02324edccef0c3ed31dbfe9e3ab8e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Belo Horizonte, MG, Brasil&lt;/div&gt;`)[0];
#                 popup_5e421f98c5e86f542ce8f4d50204bb0f.setContent(html_0de02324edccef0c3ed31dbfe9e3ab8e);
#
#
#
#         marker_99df3b52d9253aa025a54d6623743df8.bindPopup(popup_5e421f98c5e86f542ce8f4d50204bb0f)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscre
